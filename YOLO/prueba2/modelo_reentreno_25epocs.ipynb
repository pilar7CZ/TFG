# %%
# !pip install supervision ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 11.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
import sys
import os

import supervision as sv
import cv2

from PIL import Image

from ultralytics import YOLO

# %%
print(sys.executable)
print(os.getcwd())

# %%
#LOAD A PRETRAINDED MODEL
model_pt = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 101MB/s]

# %%
#res_val_pt = model_pt.val()

# %%
res_pt = model_pt.train(data="coco128.yaml",epochs=25, fliplr=0.5,
                        flipud=0.5, degrees=75)
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
res_val_pt = model_pt.val()
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:35<00:00,  4.48s/it]
#                    all        128        929       0.66      0.509      0.597      0.435
#                 person         61        254      0.796      0.657      0.763       0.54
#                bicycle          3          6       0.63      0.333      0.309      0.249
#                    car         12         46      0.857      0.217      0.273      0.167
#             motorcycle          4          5      0.625        0.6      0.881       0.66
#               airplane          5          6      0.662      0.656      0.802      0.585
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta_personas = '/content/drive/My Drive/Colab Notebooks/personas.jpg'
ruta_bus = '/content/drive/My Drive/Colab Notebooks/autobus.jpg'
ruta_coche = '/content/drive/My Drive/Colab Notebooks/coche102.jpg'
ruta_coche101 = '/content/drive/My Drive/Colab Notebooks/coche101.jpeg'

# %%
img_personas2 = Image.open(ruta_personas)
res_personas2 = model_pt.predict(source=img_personas2, save=True, save_txt=True)

img_bus2 = Image.open(ruta_bus)
res_bus2 = model_pt.predict(source=img_bus2, save=True, save_txt=True)

img_coche2 = Image.open(ruta_coche)
res_coche2 = model_pt.predict(source=img_coche2, save=True, save_txt=True)

img_coche101 = Image.open(ruta_coche101)
res_coche101 = model_pt.predict(source=img_coche101, save=True, save_txt = True)
# Out:
# 0: 448x640 6 persons, 349.9ms
# Speed: 4.9ms preprocess, 349.9ms inference, 5.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/train3
# 1 label saved to runs/detect/train3/labels
#
# 0: 384x640 1 person, 5 cars, 1 bus, 257.8ms
# Speed: 4.3ms preprocess, 257.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train4
# 1 label saved to runs/detect/train4/labels
#
# 0: 384x640 33 cell phones, 458.2ms
# Speed: 8.7ms preprocess, 458.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train5
# 1 label saved to runs/detect/train5/labels
#
# 0: 448x640 1 person, 43 cars, 3 buss, 1 truck, 519.6ms
# Speed: 11.0ms preprocess, 519.6ms inference, 9.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/train6
# 1 label saved to runs/detect/train6/labels

# %%
# !scp -r /content/runs '/content/drive/My Drive/Colab Notebooks/res/modelopretrainedmuchasepocas'

# %%
annotated_image_bus = res_bus2[0].plot()
sv.plot_image(annotated_image_bus)

# %%
annotated_image_personas = res_personas2[0].plot()
sv.plot_image(annotated_image_personas)

# %%
annotated_image_coche = res_coche2[0].plot()
sv.plot_image(annotated_image_coche)

# %%
annotated_image_coche101 = res_coche101[0].plot()
sv.plot_image(annotated_image_coche101)
